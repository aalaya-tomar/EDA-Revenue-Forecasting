# %%
# !unzip '/content/archive (11).zip'
# Out:
# Archive:  /content/archive (11).zip
#   inflating: Web Analytic_Dataset.csv

# %%
path='/content/Web Analytic_Dataset.csv'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[10,4]

# %%
df=pd.read_csv(path,index_col=False)

df.head()
# Out:
#   Source / Medium  Year  Month of the year    Users New Users Sessions  \
# 0               A  2019                 11  126,870   104,020  194,667
# 1               A  2020                  5  120,625    98,574  194,114
# 2               A  2019                 10  123,361   104,308  181,175
# 3               A  2019                  9  106,551    88,428  170,329
# 4               A  2020                  6  102,123    82,461  163,446
#
#   Bounce Rate Pageviews Avg. Session Duration Conversion Rate (%)  \
# 0      71.59%   455,159              00:01:11                 0.2
# 1      64.56%   559,509              00:01:32                0.69
# 2      41.91%   368,907              00:01:05                0.26
# 3      75.92%   368,803              00:01:01                0.18
# 4      67.10%   425,410              00:01:20                 0.7
#
#   Transactions  Revenue Quantity Sold
# 0          394   83,244           482
# 1        1,347  203,552         2,402
# ...

# %%
plt.style.use('dark_background')
sns.countplot(x='Source / Medium',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Year',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Source / Medium        250 non-null    object
#  1   Year                   250 non-null    int64
#  2   Month of the year      250 non-null    int64
#  3   Users                  250 non-null    object
#  4   New Users              250 non-null    object
#  5   Sessions               250 non-null    object
#  6   Bounce Rate            250 non-null    object
#  7   Pageviews              250 non-null    object
#  8   Avg. Session Duration  250 non-null    object
#  9   Conversion Rate (%)    250 non-null    object
#  10  Transactions           250 non-null    object
#  11  Revenue                250 non-null    object
#  12  Quantity Sold          250 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 25.5+ KB

# %%
int('126,870'.replace(',',''))
# Out:
# 126870

# %%
cols = ['Users',	'New Users',	'Sessions'	,'Pageviews' ,'Transactions',	'Revenue'	,'Quantity Sold']

for col in cols:
  df[col] = df[col].apply(lambda x:int(x.replace(',','')) if type(x)==str else x)

# %%
df.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#   Bounce Rate  Pageviews Avg. Session Duration Conversion Rate (%)  \
# 0      71.59%     455159              00:01:11                 0.2
# 1      64.56%     559509              00:01:32                0.69
# 2      41.91%     368907              00:01:05                0.26
# 3      75.92%     368803              00:01:01                0.18
# 4      67.10%     425410              00:01:20                 0.7
#
#    Transactions  Revenue  Quantity Sold
# 0           394    83244            482
# 1          1347   203552           2402
# ...

# %%
df[df['Conversion Rate (%)']=='<0.01']
# Out:
#    Source / Medium  Year  Month of the year  Users  New Users  Sessions  \
# 46               D  2020                  6  15117      14145     22828
#
#    Bounce Rate  Pageviews Avg. Session Duration Conversion Rate (%)  \
# 46      85.94%      27839              00:00:48               <0.01
#
#     Transactions  Revenue  Quantity Sold
# 46             2      290              2

# %%
df['Conversion Rate (%)'].replace('<0.01',0.01,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Source / Medium        250 non-null    object
#  1   Year                   250 non-null    int64
#  2   Month of the year      250 non-null    int64
#  3   Users                  250 non-null    int64
#  4   New Users              250 non-null    int64
#  5   Sessions               250 non-null    int64
#  6   Bounce Rate            250 non-null    object
#  7   Pageviews              250 non-null    int64
#  8   Avg. Session Duration  250 non-null    object
#  9   Conversion Rate (%)    250 non-null    object
#  10  Transactions           250 non-null    int64
#  11  Revenue                250 non-null    int64
#  12  Quantity Sold          250 non-null    int64
# dtypes: int64(9), object(4)
# memory usage: 25.5+ KB

# %%
float('71.59%'.replace('%',''))
# Out:
# 71.59

# %%
cols2=['Bounce Rate']
for col in cols2:
  df[col] = df[col].apply(lambda x:float(x.replace('%','')) if type(x)==str else x)

# %%
df['Conversion Rate (%)'] = df['Conversion Rate (%)'].astype(float)

# %%
df.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews Avg. Session Duration  Conversion Rate (%)  \
# 0        71.59     455159              00:01:11                 0.20
# 1        64.56     559509              00:01:32                 0.69
# 2        41.91     368907              00:01:05                 0.26
# 3        75.92     368803              00:01:01                 0.18
# 4        67.10     425410              00:01:20                 0.70
#
#    Transactions  Revenue  Quantity Sold
# 0           394    83244            482
# ...

# %%
df.dtypes
# Out:
# Source / Medium           object
# Year                       int64
# Month of the year          int64
# Users                      int64
# New Users                  int64
# Sessions                   int64
# Bounce Rate              float64
# Pageviews                  int64
# Avg. Session Duration     object
# Conversion Rate (%)      float64
# Transactions               int64
# Revenue                    int64
# Quantity Sold              int64
# dtype: object

# %%
df['DateTime'] = pd.to_datetime(df['Avg. Session Duration'])

df.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews Avg. Session Duration  Conversion Rate (%)  \
# 0        71.59     455159              00:01:11                 0.20
# 1        64.56     559509              00:01:32                 0.69
# 2        41.91     368907              00:01:05                 0.26
# 3        75.92     368803              00:01:01                 0.18
# 4        67.10     425410              00:01:20                 0.70
#
#    Transactions  Revenue  Quantity Sold            DateTime
# ...

# %%
df['hr'] = df['DateTime'].dt.hour
df['min'] = df['DateTime'].dt.minute
df['sec'] = df['DateTime'].dt.second

# %%
df.head(10)
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
# 5               A  2019                 12   91043      70326    142637
# 6               A  2020                  1   83031      64103    133736
# 7               A  2020                  7   84343      73239    125423
# 8               A  2020                  2   82626      68145    125318
# 9               A  2020                  3   73844      61557    110546
#
#    Bounce Rate  Pageviews Avg. Session Duration  Conversion Rate (%)  \
# 0        71.59     455159              00:01:11                 0.20
# ...

# %%
df.drop(['Avg. Session Duration','DateTime'],axis=1,inplace=True)

# %%
df.head(6)
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
# 5               A  2019                 12   91043      70326    142637
#
#    Bounce Rate  Pageviews  Conversion Rate (%)  Transactions  Revenue  \
# 0        71.59     455159                 0.20           394    83244
# 1        64.56     559509                 0.69          1347   203552
# 2        41.91     368907                 0.26           477    94282
# 3        75.92     368803                 0.18           311    54971
# 4        67.10     425410                 0.70          1138   167113
# ...

# %%
df['Avg Duration'] = df['min'] + df['sec']/60
df.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews  Conversion Rate (%)  Transactions  Revenue  \
# 0        71.59     455159                 0.20           394    83244
# 1        64.56     559509                 0.69          1347   203552
# 2        41.91     368907                 0.26           477    94282
# 3        75.92     368803                 0.18           311    54971
# 4        67.10     425410                 0.70          1138   167113
#
#    Quantity Sold  hr  min  sec  Avg Duration
# 0            482   0    1   11      1.183333
# ...

# %%
df.drop(['hr'	,'min'	,'sec'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews  Conversion Rate (%)  Transactions  Revenue  \
# 0        71.59     455159                 0.20           394    83244
# 1        64.56     559509                 0.69          1347   203552
# 2        41.91     368907                 0.26           477    94282
# 3        75.92     368803                 0.18           311    54971
# 4        67.10     425410                 0.70          1138   167113
#
#    Quantity Sold  Avg Duration
# 0            482      1.183333
# 1           2402      1.533333
# ...

# %%
df.to_csv('cleaned_data.csv',index=False)

# %%
data = pd.read_csv('/content/cleaned_data.csv')

# %%
data.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews  Conversion Rate (%)  Transactions  Revenue  \
# 0        71.59     455159                 0.20           394    83244
# 1        64.56     559509                 0.69          1347   203552
# 2        41.91     368907                 0.26           477    94282
# 3        75.92     368803                 0.18           311    54971
# 4        67.10     425410                 0.70          1138   167113
#
#    Quantity Sold  Avg Duration
# 0            482      1.183333
# 1           2402      1.533333
# ...

# %%
df.describe()
# Out:
#               Year  Month of the year          Users      New Users  \
# count   250.000000         250.000000     250.000000     250.000000
# mean   2019.644000           6.540000   11295.556000    8743.856000
# std       0.479776           3.507937   24516.361198   20584.145069
# min    2019.000000           1.000000      41.000000       1.000000
# 25%    2019.000000           4.000000     302.250000     144.250000
# 50%    2020.000000           6.000000     850.500000     482.500000
# 75%    2020.000000          10.000000    7836.000000    3687.750000
# max    2020.000000          12.000000  126870.000000  104308.000000
#
#             Sessions  Bounce Rate      Pageviews  Conversion Rate (%)  \
# count     250.000000   250.000000     250.000000           250.000000
# mean    16091.296000    49.311000   44112.144000             3.138000
# std     35614.955967    20.234375   93892.520116             8.124769
# min       125.000000     0.000000     237.000000             0.000000
# ...

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True,cmap='YlGnBu')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-139-0d42214177d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
df.corr()[['Bounce Rate']].style.background_gradient(cmap='magma')
# Out:
# <ipython-input-140-27bd26fd596f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()[['Bounce Rate']].style.background_gradient(cmap='magma')
# <style type="text/css">
# #T_73e41_row0_col0 {
#   background-color: #cc3f71;
#   color: #f1f1f1;
# }
# #T_73e41_row1_col0 {
#   background-color: #721f81;
#   color: #f1f1f1;
# }
# #T_73e41_row2_col0 {
#   background-color: #d9466b;
#   color: #f1f1f1;
# }
# #T_73e41_row3_col0, #T_73e41_row4_col0 {
#   background-color: #d8456c;
#   color: #f1f1f1;
# }
# #T_73e41_row5_col0 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_73e41_row6_col0 {
#   background-color: #d3436e;
#   color: #f1f1f1;
# }
# #T_73e41_row7_col0 {
#   background-color: #2c115f;
#   color: #f1f1f1;
# }
# #T_73e41_row8_col0 {
#   background-color: #a3307e;
#   color: #f1f1f1;
# }
# ...

# %%
sns.regplot(x='Bounce Rate',y='Avg Duration',data=df)
# Out:
# <Axes: xlabel='Bounce Rate', ylabel='Avg Duration'>

# %%
sns.regplot(x='Bounce Rate',y='Conversion Rate (%)',data=df)
# Out:
# <Axes: xlabel='Bounce Rate', ylabel='Conversion Rate (%)'>

# %%
df.corr()[['Pageviews']].style.background_gradient(cmap='magma')
# Out:
# <ipython-input-143-dcbae3566907>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()[['Pageviews']].style.background_gradient(cmap='magma')
# <style type="text/css">
# #T_a3255_row0_col0 {
#   background-color: #451077;
#   color: #f1f1f1;
# }
# #T_a3255_row1_col0 {
#   background-color: #4f127b;
#   color: #f1f1f1;
# }
# #T_a3255_row2_col0 {
#   background-color: #fcf6b8;
#   color: #000000;
# }
# #T_a3255_row3_col0 {
#   background-color: #fdebac;
#   color: #000000;
# }
# #T_a3255_row4_col0 {
#   background-color: #fcf7b9;
#   color: #000000;
# }
# #T_a3255_row5_col0 {
#   background-color: #962c80;
#   color: #f1f1f1;
# }
# #T_a3255_row6_col0 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_a3255_row7_col0 {
#   background-color: #1c1044;
#   color: #f1f1f1;
# }
# #T_a3255_row8_col0 {
# ...

# %%
df.corr()[['Conversion Rate (%)']].style.background_gradient(cmap='magma')
# Out:
# <ipython-input-144-b162a835aa85>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()[['Conversion Rate (%)']].style.background_gradient(cmap='magma')
# <style type="text/css">
# #T_89ae9_row0_col0 {
#   background-color: #701f81;
#   color: #f1f1f1;
# }
# #T_89ae9_row1_col0 {
#   background-color: #651a80;
#   color: #f1f1f1;
# }
# #T_89ae9_row2_col0, #T_89ae9_row6_col0 {
#   background-color: #420f75;
#   color: #f1f1f1;
# }
# #T_89ae9_row3_col0 {
#   background-color: #451077;
#   color: #f1f1f1;
# }
# #T_89ae9_row4_col0 {
#   background-color: #440f76;
#   color: #f1f1f1;
# }
# #T_89ae9_row5_col0 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_89ae9_row7_col0 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_89ae9_row8_col0 {
#   background-color: #c03a76;
#   color: #f1f1f1;
# ...

# %%
df.corr()[['Revenue']].style.background_gradient(cmap='magma')
# Out:
# <ipython-input-145-6cdbb743d7d4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()[['Revenue']].style.background_gradient(cmap='magma')
# <style type="text/css">
# #T_88ff2_row0_col0 {
#   background-color: #2c115f;
#   color: #f1f1f1;
# }
# #T_88ff2_row1_col0 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_88ff2_row2_col0 {
#   background-color: #fc8a62;
#   color: #f1f1f1;
# }
# #T_88ff2_row3_col0 {
#   background-color: #fa815f;
#   color: #f1f1f1;
# }
# #T_88ff2_row4_col0 {
#   background-color: #fd9668;
#   color: #000000;
# }
# #T_88ff2_row5_col0 {
#   background-color: #120d31;
#   color: #f1f1f1;
# }
# #T_88ff2_row6_col0 {
#   background-color: #fd9b6b;
#   color: #000000;
# }
# #T_88ff2_row7_col0 {
#   background-color: #8c2981;
#   color: #f1f1f1;
# }
# #T_88ff2_row8_col0 {
# ...

# %%
df.hist(bins=20, figsize=(15, 10))
plt.suptitle('Histograms of Numerical Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Source / Medium', y='Sessions', data=df)
plt.title('Boxplot of Sessions by Source / Medium')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.pairplot(df[['Users', 'Sessions', 'Bounce Rate', 'Pageviews', 'Conversion Rate (%)', 'Revenue']])
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()

# %%
df.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews  Conversion Rate (%)  Transactions  Revenue  \
# 0        71.59     455159                 0.20           394    83244
# 1        64.56     559509                 0.69          1347   203552
# 2        41.91     368907                 0.26           477    94282
# 3        75.92     368803                 0.18           311    54971
# 4        67.10     425410                 0.70          1138   167113
#
#    Quantity Sold  Avg Duration
# 0            482      1.183333
# 1           2402      1.533333
# ...

# %%
df.groupby(['Year'])['Revenue','Transactions','Quantity Sold'].sum().plot.pie(subplots=True)
# Out:
# <ipython-input-150-58e9f676620a>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Year'])['Revenue','Transactions','Quantity Sold'].sum().plot.pie(subplots=True)
# array([<Axes: ylabel='Revenue'>, <Axes: ylabel='Transactions'>,
#        <Axes: ylabel='Quantity Sold'>], dtype=object)

# %%
res=df.groupby(['Year','Month of the year'])['Revenue','Transactions','Quantity Sold'].sum()
# Out:
# <ipython-input-151-703058283ce7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   res=df.groupby(['Year','Month of the year'])['Revenue','Transactions','Quantity Sold'].sum()

# %%
res=res.reset_index()
res
# Out:
#     Year  Month of the year  Revenue  Transactions  Quantity Sold
# 0   2019                  9   155796           877           1289
# 1   2019                 10   283905          1351           2007
# 2   2019                 11   270010          1154           1679
# 3   2019                 12   260688          1277           1682
# 4   2020                  1   307336          1401           1964
# 5   2020                  2   323540          1696           2670
# 6   2020                  3   277426          1681           2960
# 7   2020                  4   373345          2448           4696
# 8   2020                  5   589545          3812           7594
# 9   2020                  6   469650          3040           6001
# 10  2020                  7   266165          1770           3530
# 11  2020                  8   115788           756           1454

# %%
sns.barplot(x='Month of the year',y='Revenue',data=res,hue='Year')
# Out:
# <Axes: xlabel='Month of the year', ylabel='Revenue'>

# %%
sns.barplot(x='Month of the year',y='Transactions',data=res,hue='Year')
# Out:
# <Axes: xlabel='Month of the year', ylabel='Transactions'>

# %%
sns.barplot(x='Month of the year',y='Quantity Sold',data=res,hue='Year')
# Out:
# <Axes: xlabel='Month of the year', ylabel='Quantity Sold'>

# %%
sm = df.groupby(['Source / Medium'])['Revenue','Transactions','Quantity Sold'].sum()
sm
# Out:
# <ipython-input-156-26f5e94d75cf>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sm = df.groupby(['Source / Medium'])['Revenue','Transactions','Quantity Sold'].sum()
#                     Revenue  Transactions  Quantity Sold
# Source / Medium
# A                   1294136          7566          12133
# AA                       81             1              1
# B                    540692          2838           5086
# BB                      103             1              1
# C                    207764          1689           2887
# CC                    24440           111            272
# D                       290             2              2
# DD                     1307             9             10
# E                    197904          1148           1828
# EE                    14257            61             94
# F                    149046           823           1411
# ...

# %%
sns.barplot(x=sm.index,y='Quantity Sold',data=sm)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=sm.index,y='Revenue',data=sm)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=sm.index,y='Transactions',data=sm)
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews  Conversion Rate (%)  Transactions  Revenue  \
# 0        71.59     455159                 0.20           394    83244
# 1        64.56     559509                 0.69          1347   203552
# 2        41.91     368907                 0.26           477    94282
# 3        75.92     368803                 0.18           311    54971
# 4        67.10     425410                 0.70          1138   167113
#
#    Quantity Sold  Avg Duration
# 0            482      1.183333
# 1           2402      1.533333
# ...

# %%
cr = df.groupby(['Year','Month of the year'])['Conversion Rate (%)'].mean().reset_index()
cr
# Out:
#     Year  Month of the year  Conversion Rate (%)
# 0   2019                  9             2.875455
# 1   2019                 10             3.522174
# 2   2019                 11             2.661364
# 3   2019                 12             2.867273
# 4   2020                  1             3.070455
# 5   2020                  2             3.480500
# 6   2020                  3             3.593333
# 7   2020                  4             3.718571
# 8   2020                  5             2.588621
# 9   2020                  6             4.045556
# 10  2020                  7             4.578125
# 11  2020                  8             1.031176

# %%
sns.barplot(x='Month of the year',y='Conversion Rate (%)',data=cr,hue='Year')
# Out:
# <Axes: xlabel='Month of the year', ylabel='Conversion Rate (%)'>

# %%
ad = df.groupby(['Year','Month of the year'])['Avg Duration'].mean().reset_index()
ad
# Out:
#     Year  Month of the year  Avg Duration
# 0   2019                  9      2.530303
# 1   2019                 10      2.508696
# 2   2019                 11      2.686364
# 3   2019                 12      2.478788
# 4   2020                  1      2.459848
# 5   2020                  2      2.518333
# 6   2020                  3      2.549074
# 7   2020                  4      2.435714
# 8   2020                  5      2.600575
# 9   2020                  6      2.512963
# 10  2020                  7      2.387500
# 11  2020                  8      2.787255

# %%
sns.barplot(x='Month of the year',y='Avg Duration',data=ad,hue='Year')
# Out:
# <Axes: xlabel='Month of the year', ylabel='Avg Duration'>

# %%
sns.heatmap(df.corr(method='spearman'),annot=True,cmap='Blues')
# Out:
# <ipython-input-165-a08d3bc9346f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='spearman'),annot=True,cmap='Blues')
# <Axes: >

# %%
df['Source / Medium'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Source / Medium'>

# %%
df['Month of the year'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Month of the year'>

# %%
df.head()
# Out:
#   Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0               A  2019                 11  126870     104020    194667
# 1               A  2020                  5  120625      98574    194114
# 2               A  2019                 10  123361     104308    181175
# 3               A  2019                  9  106551      88428    170329
# 4               A  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews  Conversion Rate (%)  Transactions  Revenue  \
# 0        71.59     455159                 0.20           394    83244
# 1        64.56     559509                 0.69          1347   203552
# 2        41.91     368907                 0.26           477    94282
# 3        75.92     368803                 0.18           311    54971
# 4        67.10     425410                 0.70          1138   167113
#
#    Quantity Sold  Avg Duration
# 0            482      1.183333
# 1           2402      1.533333
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Source / Medium'] = encoder.fit_transform(df['Source / Medium'])

# %%
df.head()
# Out:
#    Source / Medium  Year  Month of the year   Users  New Users  Sessions  \
# 0                0  2019                 11  126870     104020    194667
# 1                0  2020                  5  120625      98574    194114
# 2                0  2019                 10  123361     104308    181175
# 3                0  2019                  9  106551      88428    170329
# 4                0  2020                  6  102123      82461    163446
#
#    Bounce Rate  Pageviews  Conversion Rate (%)  Transactions  Revenue  \
# 0        71.59     455159                 0.20           394    83244
# 1        64.56     559509                 0.69          1347   203552
# 2        41.91     368907                 0.26           477    94282
# 3        75.92     368803                 0.18           311    54971
# 4        67.10     425410                 0.70          1138   167113
#
#    Quantity Sold  Avg Duration
# 0            482      1.183333
# 1           2402      1.533333
# ...

# %%
encoder.inverse_transform([0])
# Out:
# array(['A'], dtype=object)

# %%
df.shape
# Out:
# (250, 13)

# %%
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
x = df.drop(['Revenue'],axis=1)
y = df['Revenue']

xgb=XGBRegressor()

# %%
from sklearn.feature_selection import RFE
rfe = RFE(xgb)
rfe.fit(x,y)
# Out:
# RFE(estimator=XGBRegressor(base_score=None, booster=None, callbacks=None,
#                            colsample_bylevel=None, colsample_bynode=None,
#                            colsample_bytree=None, device=None,
#                            early_stopping_rounds=None, enable_categorical=False,
#                            eval_metric=None, feature_types=None, gamma=None,
#                            grow_policy=None, importance_type=None,
#                            interaction_constraints=None, learning_rate=None,
#                            max_bin=None, max_cat_threshold=None,
#                            max_cat_to_onehot=None, max_delta_step=None,
#                            max_depth=None, max_leaves=None,
#                            min_child_weight=None, missing=nan,
#                            monotone_constraints=None, multi_strategy=None,
#                            n_estimators=None, n_jobs=None,
# ...

# %%
cols = x.columns[rfe.support_]

# %%
x_train,x_test,y_train,y_test = train_test_split(x[cols],y,test_size=0.3,random_state=42)
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = LinearRegression()
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgb.score(x_test,y_test)
# Out:
# 0.9720248947625504

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(xgb,x_train,y_train,cv=5)
scores
# Out:
# array([0.95248553, 0.97826045, 0.9158198 , 0.95511472, 0.90840778])

# %%
from xgboost import plot_importance
plot_importance(xgb)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
from sklearn.metrics import mean_absolute_error as mae
y_pred = xgb.predict(x_test)

mae(y_test,y_pred)
# Out:
# 1816.1362308851878

# %%
sns.scatterplot(x=y_test,y=y_pred)
# Out:
# <Axes: xlabel='Revenue'>

# %%
sns.residplot(x=y_pred,y=y_test-y_pred)
# Out:
# <Axes: ylabel='Revenue'>

# %%
sns.distplot(y_test-y_pred)
# Out:
# <ipython-input-72-f7d4a70d285b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_pred)
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
test = x.sample(1)[cols].to_numpy()
test_ = scaler.transform(test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
xgb.predict(test_)
# Out:
# array([2182.9475], dtype=float32)
